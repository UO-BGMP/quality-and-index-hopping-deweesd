# %%
# !/anaconda/bin/python

# import argparse

# parser = argparse.ArgumentParser(description= 'quality score distribution and filename')
# parser.add_argument('-c', '--column',  help="number of columns", required=True, type=int)
# parser.add_argument('-f', '--file_path', type=str, help="specifying filename_r file")
# parser.add_argument('-r', '--num_rows', help="specifies number of rows", required=True, type=int)
# args = parser.parse_args() #setting all arguments as callable 


# c = args.column
# f = args.file_path
# r = args.num_rows


#setting c and r to corresponding column and row values
c = 101
r = 363246735

import numpy as np
mean_scores = np.zeros((c,r), dtype=float) 



'''Calculate the mean scores at each position in array'''

i=0
with open("f", "r") as fh:
    
    for line in fh:
        # Walk through file, extract quality scores and build giant
        # two dimensional array holding those scores.
                           # way to seperate/strip new line char
        i+=1
        #when i/4 has a remainder of 0, print those values
        line = line.strip("\n")
        
        if i%4==0:#goes to and grabs the qual score line of fastq file
            position=0
            for character in line: #goes through each character in the extracted lines in file (qual_score line)
                phred_score = ord(character)-33 #calculate the corresponding phred score to the relative ASCII value
                mean_scores[position][int(i/4)-1] = phred_score #set the newely calculated phred score to the paired array number and index value
                position+=1 #increment by 1
        #print(mean_scores)
        
'''Calculate the mean at each index in the array and create new array'''

print("\n")
mean_1 = np.mean(mean_scores, axis=1)


#output files
with open("1294_S1_L008_R1_001" + "_q_distribution", "w") as output:
    j = 1
    for score in mean_1:
        output.write(str(j) + "\t" + str(score) + "\n")
        j += 1

# %%
#!/anaconda/bin/python

# import argparse

# parser = argparse.ArgumentParser(description= 'quality score distribution and filename')
# parser.add_argument('-c', '--column',  help="number of columns", required=True, type=int)
# parser.add_argument('-f', '--file_path', type=str, help="specifying filename_r file")
# parser.add_argument('-r', '--num_rows', help="specifies number of rows", required=True, type=int)
# args = parser.parse_args() #setting all arguments as callable 


# c = args.column
# f = args.file_path
# r = args.num_rows


#setting c and r to corresponding column and row values
c = 8
r = 1000000

import numpy as np
mean_scores = np.zeros((c,r), dtype=float) 
#var = np.zeros(101)
#stdev = np.zeros(101)


'''Calculate the mean scores at each position in array'''



i=0
with open("Undetermined_S0_R2_001_trunc.fastq", "r") as fh:
    
    for line in fh:
        # Walk through file, extract quality scores and build giant
        # two dimensional array holding those scores.
                           # way to seperate/strip new line char
        i+=1
        #if i%500000==0:#confirms if the file is extracting data from said lines
            #print(i/4, end=' ')
        #when i/4 has a remainder of 0, print those values
        line = line.strip("\n")
        
        if i%4==0:#goes to and grabs the qual score line of fastq file
            position=0
            for character in line: #goes through each character in the extracted lines in file (qual_score line)
                phred_score = ord(character)-33 #calculate the corresponding phred score to the relative ASCII value
                mean_scores[position][int(i/4)-1] = phred_score #set the newely calculated phred score to the paired array number and index value
                position+=1 #increment by 1
        #print(mean_scores)
        
'''Calculate the mean at each index in the array and create new array'''

print("\n")
mean_2 = np.mean(mean_scores, axis=1)

with open("Undetermined_S0_R2_001_trunc" + "_q_distribution", "w") as output:
    j = 0
    for score in mean_2:
        output.write(str(j) + "\t" + str(score) + "\n")
        j += 1

# %%
#!/anaconda/bin/python

# import argparse

# parser = argparse.ArgumentParser(description= 'quality score distribution and filename')
# parser.add_argument('-c', '--column',  help="number of columns", required=True, type=int)
# parser.add_argument('-f', '--file_path', type=str, help="specifying filename_r file")
# parser.add_argument('-r', '--num_rows', help="specifies number of rows", required=True, type=int)
# args = parser.parse_args() #setting all arguments as callable 


# c = args.column
# f = args.file_path
# r = args.num_rows


#setting c and r to corresponding column and row values
c = 8
r = 1000000

import numpy as np
mean_scores = np.zeros((c,r), dtype=float) 
#var = np.zeros(101)
#stdev = np.zeros(101)


'''Calculate the mean scores at each position in array'''



i=0
with open("Undetermined_S0_R3_001_trunc.fastq", "r") as fh:
    
    for line in fh:
        # Walk through file, extract quality scores and build giant
        # two dimensional array holding those scores.
                           # way to seperate/strip new line char
        i+=1
        #if i%500000==0:#confirms if the file is extracting data from said lines
            #print(i/4, end=' ')
        #when i/4 has a remainder of 0, print those values
        line = line.strip("\n")
        
        if i%4==0:#goes to and grabs the qual score line of fastq file
            position=0
            for character in line: #goes through each character in the extracted lines in file (qual_score line)
                phred_score = ord(character)-33 #"""Converts a single character into a phred score"""
                mean_scores[position][int(i/4)-1] = phred_score #set the newely calculated phred score to the paired array number and index value
                position+=1 #increment by 1
        #print(mean_scores)
        
'''Calculate the mean at each index in the array and create new array'''

print("\n")
mean_3 = np.mean(mean_scores, axis=1)

with open("Undetermined_S0_R3_001_trunc" + "_q_distribution", "w") as output:
    j = 1
    for score in mean_3:
        output.write(str(j) + "\t" + str(score) + "\n")
        j += 1

# %%
#!/anaconda/bin/python

# import argparse

# parser = argparse.ArgumentParser(description= 'quality score distribution and filename')
# parser.add_argument('-c', '--column',  help="number of columns", required=True, type=int)
# parser.add_argument('-f', '--file_path', type=str, help="specifying filename_r file")
# parser.add_argument('-r', '--num_rows', help="specifies number of rows", required=True, type=int)
# args = parser.parse_args() #setting all arguments as callable 


# c = args.column
# f = args.file_path
# r = args.num_rows



#setting c and r to corresponding column and row values
c = 38
r = 1000000

import numpy as np
mean_scores = np.zeros((c,r), dtype=float) 
#var = np.zeros(101)
#stdev = np.zeros(101)


'''Calculate the mean scores at each position in array'''



i=0
with open("Undetermined_S0_R4_001_trunc.fastq", "r") as fh:
    
    for line in fh:
        # Walk through file, extract quality scores and build giant
        # two dimensional array holding those scores.
                           # way to seperate/strip new line char
        i+=1
        #if i%500000==0:#confirms if the file is extracting data from said lines
            #print(i/4, end=' ')
        #when i/4 has a remainder of 0, print those values
        line = line.strip("\n")
        
        if i%4==0:#goes to and grabs the qual score line of fastq file
            position=0
            for character in line: #goes through each character in the extracted lines in file (qual_score line)
                phred_score = ord(character)-33 #calculate the corresponding phred score to the relative ASCII value
                mean_scores[position][int(i/4)-1] = phred_score #set the newely calculated phred score to the paired array number and index value
                position+=1 #increment by 1
        #print(mean_scores)
        
'''Calculate the mean at each index in the array and create new array'''

print("\n")
mean_4 = np.mean(mean_scores, axis=1)

with open("Undetermined_S0_R4_001_trunc" + "_q_distribution", "w") as output:
    j = 0
    for score in mean_4:
        output.write(str(j) + "\t" + str(score) + "\n")
        j += 1
